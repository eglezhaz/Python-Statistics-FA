# %% [markdown]
# # Import data
# In this Jupyter Notebook, you will learn how to import data from CSV into Jupyter Notebook

# %%
#import the package "Pandas" into Jupyter Notebook
import pandas as pd

# %%
#We import the stock data of Facebook into Jupyter Notebook. The CSV file is located in the folder called "Data" in your Workspace
#We then name the DataFrame name as 'fb'
fb = pd.DataFrame.from_csv('../data/facebook.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 #We import the stock data of Facebook into Jupyter Notebook. The CSV file is located in the folder called "Data" in your Workspace
#       2 #We then name the DataFrame name as 'fb'
# ----> 3 fb = pd.DataFrame.from_csv('../data/facebook.csv')
#
# AttributeError: type object 'DataFrame' has no attribute 'from_csv'

# %% [markdown]
# ### Instruction
# Now is your turn to import the stock price of Microsoft (microsoft.csv), of which the CSV is located in the same folder, and rename the Dataframe in "ms".

# %%
import pandas as pd

ms = pd.DataFrame.from_csv('../data/microsoft.csv')

# %%
# run this cell to ensure Microsoft's stock data is imported
print(ms.iloc[0, 0])
print(type(ms))
ms.shape

print(ms.DataFrame.dtype())


fb.loc['2015-01-02':'2015-12-31', 'Close'].plot()
fb.loc['2016-01-02':'2015-12-31', 'Close'].plot()
fb.loc['2017-01-02':'2015-12-31', 'Close'].plot()
fb.loc['2018-01-02':'2015-12-31', 'Close'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # run this cell to ensure Microsoft's stock data is imported
# ----> 2 print(ms.iloc[0, 0])
#       3 print(type(ms))
#       4 ms.shape
#
# NameError: name 'ms' is not defined

# %% [markdown]
# ** Expected output: ** 46.73
